# %%
import pandas as pd
import numpy as np
df = pd.read_csv('realtor-data.csv')

# %%
df.head(4)
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0  \
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0

# %%
df['state'].unique()
# Out:
# array(['Puerto Rico', 'Virgin Islands', 'Massachusetts', 'Connecticut',
#        'New Hampshire', 'Vermont', 'New Jersey', 'New York',
#        'South Carolina', 'Tennessee', 'Rhode Island', 'Virginia',
#        'Wyoming', 'Maine'], dtype=object)

# %%
df.isnull().sum()
# Out:
# status                 0
# bed                55924
# bath               54682
# acre_lot           66123
# city                  52
# state                  0
# zip_code             197
# house_size         53443
# prev_sold_date    196411
# price                  0
# dtype: int64

# %%
df['bed']=df['bed'].fillna(df['bed'].mean()) #media

# %%
df['bath']=df['bath'].fillna(df['bath'].mean()) #media

# %%
df['house_size']=df['house_size'].fillna(df['house_size'].mean()) #media

# %%
df['prev_sold_date']=df['prev_sold_date'].fillna(df['prev_sold_date'].mode()[0]) #rellenar

# %%
df['prev_sold_date'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 305995    False
# 305996    False
# 305997    False
# 305998    False
# 305999    False
# Name: prev_sold_date, Length: 306000, dtype: bool

# %%
df.head(40)
# Out:
#       status  bed  bath  acre_lot           city        state  zip_code
# 0   for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0  \
# 1   for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2   for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3   for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4   for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# 5   for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
# 6   for_sale  3.0   1.0      0.20         Ciales  Puerto Rico     639.0
# 7   for_sale  3.0   2.0      0.08          Ponce  Puerto Rico     731.0
# 8   for_sale  2.0   1.0      0.09          Ponce  Puerto Rico     730.0
# 9   for_sale  5.0   3.0      7.46     Las Marias  Puerto Rico     670.0
# 10  for_sale  3.0   2.0     13.39        Isabela  Puerto Rico     662.0
# 11  for_sale  3.0   2.0      0.08     Juana Diaz  Puerto Rico     795.0
# ...

# %%
df.isnull().sum()
# Out:
# status                0
# bed                   0
# bath                  0
# acre_lot          66123
# city                 52
# state                 0
# zip_code            197
# house_size            0
# prev_sold_date        0
# price                 0
# dtype: int64

# %%
df['acre_lot']=df['acre_lot'].fillna(df['acre_lot'].mean()) #media

# %%
df['city']=df['city'].fillna('Desconocido') #Nueva Cate

# %%
df['zip_code']=df['zip_code'].fillna(df['zip_code'].mean()) #media

# %%
df.isnull().sum()
# Out:
# status            0
# bed               0
# bath              0
# acre_lot          0
# city              0
# state             0
# zip_code          0
# house_size        0
# prev_sold_date    0
# price             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306000 entries, 0 to 305999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          306000 non-null  object
#  1   bed             306000 non-null  float64
#  2   bath            306000 non-null  float64
#  3   acre_lot        306000 non-null  float64
#  4   city            306000 non-null  object
#  5   state           306000 non-null  object
#  6   zip_code        306000 non-null  float64
#  7   house_size      306000 non-null  float64
#  8   prev_sold_date  306000 non-null  object
#  9   price           306000 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 23.3+ MB

# %%
df = pd.get_dummies(df, columns=['status'], dtype=int) #converti valores a numeros

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306000 entries, 0 to 305999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   bed                    306000 non-null  float64
#  1   bath                   306000 non-null  float64
#  2   acre_lot               306000 non-null  float64
#  3   city                   306000 non-null  object
#  4   state                  306000 non-null  object
#  5   zip_code               306000 non-null  float64
#  6   house_size             306000 non-null  float64
#  7   prev_sold_date         306000 non-null  object
#  8   price                  306000 non-null  float64
#  9   status_for_sale        306000 non-null  int32
#  10  status_ready_to_build  306000 non-null  int32
# dtypes: float64(6), int32(2), object(3)
# memory usage: 23.3+ MB

# %%
df.head(20)
# Out:
#     bed  bath  acre_lot           city        state  zip_code   house_size
# 0   3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0   920.000000  \
# 1   4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0  1527.000000
# 2   2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0   748.000000
# 3   4.0   2.0      0.10          Ponce  Puerto Rico     731.0  1800.000000
# 4   6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0  2225.678298
# 5   4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0  2520.000000
# 6   3.0   1.0      0.20         Ciales  Puerto Rico     639.0  2040.000000
# 7   3.0   2.0      0.08          Ponce  Puerto Rico     731.0  1050.000000
# 8   2.0   1.0      0.09          Ponce  Puerto Rico     730.0  1092.000000
# 9   5.0   3.0      7.46     Las Marias  Puerto Rico     670.0  5403.000000
# 10  3.0   2.0     13.39        Isabela  Puerto Rico     662.0  1106.000000
# ...
